# %% [markdown]
# [Python Plotting latitude and longitude from csv on map using basemap, folium, geopandas and plotly](https://kanoki.org/python-plotting-latitude-and-longitude-from-csv-on-map-using-basemap-folium-geopandas-and-plotly)
#
# [Latitude and Longitude](https://www.youtube.com/watch?v=tuvKtMtEdoE)

# %%
# https://kanoki.org/python-plotting-latitude-and-longitude-from-csv-on-map-using-basemap-folium-geopandas-and-plotly
#[Python Plotting latitude and longitude from csv on map using basemap, folium, geopandas and plotly](Python Plotting latitude and longitude from csv on map using basemap, folium, geopandas and plotly)

# importing the libraries
# %matplotlib inline
import pandas as pd
from mpl_toolkits.basemap import Basemap    # pip install basemap
import matplotlib.pyplot as plt

# %%
# setting the filepath and loading csv
countries = 'world_country_and_usa_states_latitude_and_longitude_values.csv'
data = pd.read_csv(countries)
data
# Out:
#     country_code   latitude  longitude               country usa_state_code  \
# 0             AD  42.546245   1.601554               Andorra             AK
# 1             AE  23.424076  53.847818  United Arab Emirates             AL
# 2             AF  33.939110  67.709953           Afghanistan             AR
# 3             AG  17.060816 -61.796428   Antigua and Barbuda             AZ
# 4             AI  18.220554 -63.068615              Anguilla             CA
# ..           ...        ...        ...                   ...            ...
# 240           YE  15.552727  48.516388                 Yemen            NaN
# 241           YT -12.827500  45.166244               Mayotte            NaN
# 242           ZA -30.559482  22.937506          South Africa            NaN
# 243           ZM -13.133897  27.849332                Zambia            NaN
# 244           ZW -19.015438  29.154857              Zimbabwe            NaN
#
#      usa_state_latitude  usa_state_longitude   usa_state
# ...

# %%
# setting the size of the map
fig = plt.figure(figsize=(12,9))


# creating the map - setting latitude and longitude
m = Basemap(projection = 'mill', llcrnrlat = -90, urcrnrlat = 90, llcrnrlon = -180, urcrnrlon = 180, resolution = 'c')

# %%
# drawing the coastline
m.drawcoastlines()
m.drawcountries(color='gray')
m.drawstates(color='gray')

# creating variable for latitude and longitude to list
lat = data['latitude'].tolist()
lon = data['longitude'].tolist()

# plotting the map
m.scatter(lon, lat, latlon = True, s = 10, c = 'red', marker = 'o', alpha = 1)

plt.show()

# %% [markdown]
# [plotting maps with geopandas and matplotlib](https://www.youtube.com/watch?v=5G-1k4CNChI)
