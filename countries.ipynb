# %%
import pandas as pd
import random
from IPython.display import IFrame

df_countries = pd.read_csv('countries_of_the_world.csv')
# df_countries.info()

pd.set_option('display.max_rows', None)            # None means ALL rows
# df_countries['Literacy (%)']
df_countries[['Country', 'Literacy (%)', 'Phones (per 1000)']]
# Out:
#                                Country Literacy (%) Phones (per 1000)
# 0                         Afghanistan          36,0               3,2
# 1                             Albania          86,5              71,2
# 2                             Algeria          70,0              78,1
# 3                      American Samoa          97,0             259,5
# 4                             Andorra         100,0             497,2
# 5                              Angola          42,0               7,8
# 6                            Anguilla          95,0             460,0
# 7                   Antigua & Barbuda          89,0             549,9
# 8                           Argentina          97,1             220,4
# 9                             Armenia          98,6             195,7
# 10                              Aruba          97,0             516,1
# 11                          Australia         100,0             565,5
# ...
